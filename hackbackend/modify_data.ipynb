# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./savecsv.csv')

# %%
df
# Out:
#     stress_score  sleep_hours  working_hours  free_time  holidays_per_year  \
# 0             12            8             10          4                  3
# 1             15            5             12          5                  1
# 2             18            7             10          2                  2
# 3             21           10              5          5                  0
# 4             27            1             10          1                  0
# 5             15            8             10          2                  1
# 6             16            7              9          2                  1
# 7             17            7              8          1                  1
# 8             18            8              9          2                  1
# 9             16            6             10          3                  2
# 10            15            7             11          2                  1
# ...

# %%
def modify(x) :
    max = 27.0
    return (x/max)*21.0

# %%
type(df['stress_score'][1])
# Out:
# numpy.int64

# %%
for i in range(np_df.shape[0]) :
    df['stress_score'][i] = modify(df['stress_score'][i])

# %%
df.to_csv('save2csv.csv',header=True , index = False)

# %%
p = pd.read_csv('./save2csv.csv')

# %%
p.head()
# Out:
#    stress_score  sleep_hours  working_hours  free_time  holidays_per_year  \
# 0             9            8             10          4                  3
# 1            11            5             12          5                  1
# 2            14            7             10          2                  2
# 3            16           10              5          5                  0
# 4            21            1             10          1                  0
#
#    stress
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1

# %% [markdown]
# # MODIFYING COLUMN VALUES

# %%
# cols = df.columns
# for c in cols :
#     print c

# np_df = np.asarray(df)
# def modify(x) :
#     max = 27.0
#     return (x/max)*21.0
# for i in range(np_df.shape[0]) :
#     np_df[i,0] = modify(np_df[i,0])
# print len(cols)
# final = {}
# for i in range(len(cols)) :
#     final[cols[i]] = np_df[:,i]
# pd_final = pd.DataFrame(final)

# %%
# Out:
#     free_time  holidays_per_year  sleep_hours  stress  stress_score  \
# 0           4                  3            8       0             9
# 1           5                  1            5       0            11
# 2           2                  2            7       1            14
# 3           5                  0           10       1            16
# 4           1                  0            1       1            21
# 5           2                  1            8       0            11
# 6           2                  1            7       0            12
# 7           1                  1            7       0            13
# 8           2                  1            8       1            14
# 9           3                  2            6       0            12
# 10          2                  1            7       0            11
# 11          2                  0            8       0            14
# 12          3                  0            8       0            14
# ...
